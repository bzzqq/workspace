# %%
teams = ['张三', '王伟', '张三', '李娜', '张三', '陈芳']
while '张三' in teams:
    teams.remove('张三')
print(teams)

# %%
# 查找未处理订单
orders = ['OD01','OD02','OD03','OD04','OD05']
processed_order = ['OD02','OD03','OD07','OD08']
for order in orders:
    if order in processed_order:
        print(f'订单{order}已处理！')
print('订单检查完毕！')

# %%
registered_users = [admin, ]
user_password = [123456]
username = "admin"
password = "123456"

if username in registered_users:      # 外层if
    if password == user_password:     # 内层if
        print("登录成功")
