# %%
students_scores = {
    "张三": {"数学": 92, "语文": 88, "英语": 95},
    "李四": {"数学": 85, "语文": 76, "英语": 89},
    "王五": {"数学": 78, "语文": 82, "英语": 80},
    "赵六": {"数学": 90, "语文": 91, "英语": 93},
}

# %%
scores = {"张三": 92, "李四": 85, "王五": 78, "赵六": 90}
scores.items()
# Out:
# dict_items([('张三', 92), ('李四', 85), ('王五', 78), ('赵六', 90)])

# %%
names = []
scores = {"张三": 92, "李四": 85, "王五": 78}
for key in scores.keys():
    names.append(key)
print(names)
# Out:
# ['张三', '李四', '王五']

# %%
scores = {"张三": 92, "李四": 85, "王五": 78, "赵六": 90}
for name in scores.keys():
    score = scores[name]
    print(f"{name}的成绩是{score}分。")

# %%
scores = {"张三": 92, "李四": 85, "王五": 78}
for name, score in scores.items():
    print(f"{name}的成绩是{score}分。")

# %%
scores = {"张三": 92, "李四": 85, "王五": 78}
for item in scores.______():
    print(item)

# %%
dict = {"abandon": "丢弃；放弃，抛弃", "ability": "能力"}

# %%
data = eval('{"abandon": "丢弃；放弃，抛弃", "ability": "能力"}')
print(data)
print(type(data))
print(data["abandon"])

# %%
data = eval('{"年龄": 18, "身高": 188, "性别": "男"}')
print(data)
print(type(data))

# %%
products = {"笔记本": 4999, "手机": 2999, "键盘": 299, "鼠标": 199}
prices = []
for value in products.values():
    prices.append(value)
print(prices)

# %%
products = {"笔记本": 4999, "手机": 2999, "键盘": 299, "鼠标": 199}
for name in products.keys():
    score = products[name]
    print(f"{name}的价格是{score}元。")

# %%
scores = {"zhang": 92, "wang": 85, "li": 78, "zhao": 90}
print(sorted(scores.keys()))
print(sorted(scores.values()))
print(sorted(scores.items()))
print(sorted(scores.items(), key=lambda x: x[1]))
print(dict(sorted(scores.items(), key=lambda x: x[1])))
for name in sorted(scores.values()):
    print(name)

# %%
favorites = {'jen': 'python', 'edward': 'rust'}
for name in sorted(favorites.keys()):
    language = favorites[name].title()
    print(f"{name} loves {language}.")

# %%
# 字典嵌套列表
students_buy = {
    "张三": ["羽毛球", "笔记本", "钢笔"],
    "李四": ["橡皮", "转笔刀", "直尺"],
    "王五": ["圆规", "跳绳", "乒乓球"],
    "赵六": ["球鞋", "手套"],
}

# %%
# 列表嵌套字典
students_scores = [
    {"姓名": "张三", "数学": 92, "语文": 88, "英语": 95},
    {"姓名": "李四", "数学": 85, "语文": 76, "英语": 89},
    {"姓名": "王五", "数学": 78, "语文": 82, "英语": 80},
    {"姓名": "赵六", "数学": 90, "语文": 91, "英语": 93},
]

# %%
students_0 = {"姓名": "张三", "数学": 92, "语文": 88, "英语": 95}
students_1 = {"姓名": "李四", "数学": 85, "语文": 76, "英语": 89}
students_2 = {"姓名": "王五", "数学": 78, "语文": 82, "英语": 80}
students_3 = {"姓名": "赵六", "数学": 90, "语文": 91, "英语": 93}

# %%
students_scores = (
    {"姓名": "张三", "数学": 92, "语文": 88, "英语": 95},
    {"姓名": "李四", "数学": 85, "语文": 76, "英语": 89}
)
print(students_scores[0])

# %%
fruits = ["apple", "banana", "cherry"]
if "banana" in fruits:
    print("yes")  # 输出：yes

# %%
scores = {"张三":92, "李四": 85, "王五": 78, "赵六": 90}
del scores["李四"]
print(scores)
# Out:
# {'张三': 92, '王五': 78, '赵六': 90}

# %%
scores = {"张三":92, "李四": 85, "王五": 78, "赵六": 90}
scores("张三") = 100
scores["张三"] = 100
scores.get("张三") = 100
scores.get("张三", 0) = 100
