# %%
price = 19.995
print(round(price, 2))      # 20.0 (输出其浮点数的最短表示)

print(f"{price:.2f}")       # "20.00" (格式化为字符串)
# Out:
# 20.0
# 20.00

# %%
print(round(2.675, 2))  # 2.67 (不是 2.68)
# 实际 2.675 在计算机中是 2.6749999999999998
