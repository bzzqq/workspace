# %%
batch1 = float(input("请输入第一批货物的重量："))
batch2 = float(input("请输入第二批货物的重量："))
total_weight = batch1 + batch2
print(f"货物总重量是{total_weight}公斤")
# Out:
# 货物总重量是3.0公斤

# %%
container_volume = 68.8     # 集装箱容积（立方米）  
loaded_volume = 45.3  
utilization = loaded_volume / container_volume  
print(f"装载率：{utilization:.1%}")  # 输出格式化为百分比
# Out:
# 装载率：65.8%

# %%
customer = input("请输入客户名称：")
weight = float(input("请输入货物重量（公斤）："))
destination = input("请输入目的地：")
print(f"{customer}的{weight}公斤货物将发往{destination}")

# %%
item_name = "医用疫苗"
storage_temp = "-20℃"
quantity = 1500
is_urgent = True

info_card = f"""
货物名称：{item_name}  
存储要求：{storage_temp}  
当前库存：{quantity}箱  
紧急程度：{'紧急' if is_urgent else '常规'}  
"""
print(info_card)
# Out:
# 货物名称：医用疫苗
# 存储要求：-20℃
# 当前库存：1500箱
# 紧急程度：紧急

# %%
is_dangerous = True  
is_licensed = False  
can_transport = is_dangerous and is_licensed  
print("允许运输:", can_transport)
# Out:
# 允许运输: False

# %%
current_stock = 500  
# 入库操作  
current_stock += 200
# 出库操作  
current_stock -= 150  
print("当前库存:", current_stock)
# Out:
# 当前库存: 550

# %%
MIN_STOCK = 100  
current_stock = 85  
if current_stock < MIN_STOCK:  
    print("警告：库存低于安全阈值！需补货")
# Out:
# 警告：库存低于安全阈值！需补货

# %%
is_dangerous = True  
is_licensed = False  
can_transport = is_dangerous and is_licensed  
print("允许运输:", can_transport)
# Out:
# 允许运输: False
