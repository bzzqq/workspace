# %%
name = "张三"
age = 18
tel = 13166568898
score = 90.5

# %%
x = 5
y = 10
z = x + y     # 计算x + y，把结果赋值给z
print(z)      # 输出：15
# Out:
# 15

# %%
x = 5
y = 10
print(x + y)      # 输出：15
# Out:
# 15

# %%
x = 5
x = x + 1
print(x)
# 输出：6
# Out:
# 6

# %%
a = 4
a = a + 2
a = a - 2
a = a * 2
a = a / 2
print(a)
# Out:
# 4.0

# %%
a = 4
a += 2
a -= 2
a *= 2
a /= 2
print(a)
# Out:
# 4.0

# %%
a = 1
a = 2
a = 3
a = 4
a = 5
print(a)
# Out:
# 5

# %%
# a、b、c都赋值0
a = b = c = 0
# 分别赋值
x, y, z = 1, 2, 3  # x=1，y=2，z=3

# %%
print("姓名：张三")
print("欢迎张三来上课")
print("欢迎张三来到Python课堂！")
# Out:
# 姓名：张三
# 欢迎张三来上课
# 张三听课很认真

# %%
name = "张三"
print(f"姓名：{name}")
print(f"欢迎{name}来上课")
print(f"欢迎{name}来到Python课堂！")
# Out:
# 姓名：张三
# 欢迎张三来上课
# 欢迎张三来到Python课堂！
