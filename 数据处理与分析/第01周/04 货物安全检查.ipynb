# %%
is_fragile = True       # 是否易碎品  
is_dangerous = False    # 是否危险品  
needs_special_handling = is_fragile or is_dangerous  
print("需要特殊处理:", needs_special_handling)  # 输出True
# Out:
# 需要特殊处理: True
