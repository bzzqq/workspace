# %%
# 货物名称：医用疫苗  
# 存储要求：-20℃  
# 当前库存：1500箱  
# 紧急程度：紧急 

item_name = "医用疫苗"  
storage_temp = "-20℃"  
quantity = 1500  
is_urgent = True

print(f"货物名称：{item_name}")
print(f"存储要求：{storage_temp}")
print(f"当前库存：{quantity}箱")
print(f"紧急程度：{'紧急' if is_urgent else '常规'}")

# %%
# 货物名称：医用疫苗  
# 存储要求：-20℃  
# 当前库存：1500箱  
# 紧急程度：紧急 

item_name = "医用疫苗"  
storage_temp = "-20℃"  
quantity = 1500  
is_urgent = True

print(f"货物名称：{item_name}\n存储要求：{storage_temp}\n当前库存：{quantity}箱\n紧急程度：{'紧急' if is_urgent else '常规'}")

# %%
# 货物名称：医用疫苗  
# 存储要求：-20℃  
# 当前库存：1500箱  
# 紧急程度：紧急 

item_name = "医用疫苗"  
storage_temp = "-20℃"  
quantity = 1500  
is_urgent = True  

print(f"""  
货物名称：{item_name}  
存储要求：{storage_temp}  
当前库存：{quantity}箱  
紧急程度：{'紧急' if is_urgent else '常规'}  
""")

# %%
item_name = "医用疫苗"  
storage_temp = "-20℃"  
quantity = 1500  
is_urgent = True  

info_card = f"""  
货物名称：{item_name}  
存储要求：{storage_temp}  
当前库存：{quantity}箱  
紧急程度：{'紧急' if is_urgent else '常规'}  
"""  
print(info_card)
