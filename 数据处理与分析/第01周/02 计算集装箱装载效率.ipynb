# %%
container_volume = 68.8     # 集装箱容积（立方米）  
loaded_volume = 45.3  
utilization = loaded_volume / container_volume
print(f"装载率：{utilization}")  
print(f"装载率：{utilization:.1%}")  # 输出格式化为百分比
print(f"装载率：{utilization:.3f}")  # 输出格式化为3位小数
print(f"装载率：{utilization:.3e}")  # 输出格式化为科学计数
# Out:
# 装载率：0.6584302325581395
# 装载率：65.8%
# 装载率：0.658
# 装载率：6.584e-01
