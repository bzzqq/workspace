# %%
batch1 = 2300  # 公斤  
batch2 = 1750.5  
total_weight = batch1 + batch2
print(f"货物总重量是{total_weight}公斤")
# Out:
# 货物总重量是4050.5公斤

# %%
batch1 = input("请输入第一批货物的重量")
batch2 = input("请输入第二批货物的重量")  
total_weight = batch1 + batch2
print(f"货物总重量是{total_weight}公斤")
# Out:
# 货物总重量是100200公斤

# %%
batch1 = input("请输入第一批货物的重量")
batch2 = input("请输入第二批货物的重量")  
batch1 = int(batch1)
batch2 = int(batch2)
total_weight = batch1 + batch2
print(f"货物总重量是{total_weight}公斤")
# Out:
# 货物总重量是300公斤

# %%
batch1 = int(input("请输入第一批货物的重量"))
batch2 = int(input("请输入第二批货物的重量"))
total_weight = batch1 + batch2
print(f"货物总重量是{total_weight}公斤")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 2
#       1 batch1 = int(input("请输入第一批货物的重量"))
# ----> 2 batch2 = int(input("请输入第二批货物的重量"))
#       3 total_weight = batch1 + batch2
#       4 print(f"货物总重量是{total_weight}公斤")
#
# ValueError: invalid literal for int() with base 10: '200.5'

# %%
batch1 = float(input("请输入第一批货物的重量"))
batch2 = float(input("请输入第二批货物的重量"))
total_weight = batch1 + batch2
print(f"货物总重量是{total_weight}公斤")
# Out:
# 货物总重量是200.5公斤
