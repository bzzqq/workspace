# %%
# 期望输出 运单状态码：SH202309北京
shipment_id = "SH202309"
destination = "北京"
print("运单状态码：" + shipment_id + destination)
# Out:
# 运单状态码：SH202309北京

# %%
# +号不能连接数字和字符串
shipment_id = 202309
destination = "北京"
print("运单状态码：" + shipment_id + destination)

# %%
# +号不能连接数字和字符串
shipment_id = 202309
destination = "北京"
print("运单状态码：" + str(shipment_id) + destination)
# Out:
# 运单状态码：202309北京

# %%
# 期望输出 运单状态码：SH202309，目的地：北京
shipment_id = "SH202309"
destination = "北京"
print("运单状态码：" + shipment_id + "，目的地：" + destination)

# %%
# 期望输出 运单状态码：SH202309，目的地：北京
shipment_id = "SH202309"
destination = "北京"
print(f"运单状态码：{shipment_id}，目的地：{destination}")
# Out:
# 运单状态码：SH202309，目的地：北京
