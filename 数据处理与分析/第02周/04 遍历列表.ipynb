# %%
orders = ["订单A", "订单B", "订单C", "订单D", "订单E"]

# 遍历待处理订单  
for order in orders:  
    print(f"正在处理：{order}")
# Out:
# 正在处理：订单A
# 正在处理：订单B
# 正在处理：订单C
# 正在处理：订单D
# 正在处理：订单E

# %%
orders = ["订单A", "订单B", "订单C", "订单D", "订单E"]

# 遍历待处理订单
for order in orders:
    print(f"正在处理：{order}")
    print(f"处理完成：{order}")

# %%
orders = ["订单A", "订单B", "订单C", "订单D", "订单E"]

# 遍历待处理订单
for order in orders:
    print(f"正在处理：{order}")
    print(f"处理完成：{order}")
    print('所有订单已完成！')
