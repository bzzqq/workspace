# %%
# 仓库A的货物库存列表  
inventory = ["包装箱", "托盘", "叉车电池"]  
print("初始库存：", inventory)  
print("第2个货位的货物：", inventory[1])

# %%
# 仓库A的货物库存列表  
inventory = ["包装箱", "托盘", "叉车电池"]
print("第2个货位的货物：", inventory[1])
print("第2个货位的货物：" + inventory[1])

# %%
# 仓库A的货物库存列表  
inventory = ["包装箱", "托盘", "叉车电池"]  
print("第2个货位的货物：", inventory[1])
print("第2个货位的货物：" + inventory[1])
print("初始库存：", inventory)  
print("初始库存：" + inventory)

# %%
# 仓库A的货物库存列表  
inventory = ["包装箱", "托盘", "叉车电池"]

# 入库操作  
inventory.append("安全帽")            # 末尾添加  
inventory.insert(1, "扫描枪")         # 插入到索引1位置  
print("更新后库存:", inventory)

# 出库操作  
removed_item = inventory.pop(2)      # 移除索引2的货物  
inventory.remove("叉车电池")          # 按值移除  
print("更新后库存:", inventory)
