# %%
stock_prices = [100, 102, 101, 105, 108, 107]  # 按时间正序
stock_prices.reverse()  # 最新的在前
print(f"最新价格: {stock_prices[0]}")  # 107
print(f"最近5次价格: {stock_prices[:5]}")
# Out:
# 最新价格: 107
# 最近5次价格: [107, 108, 105, 101, 102]

# %%
fruits = ("苹果", "香蕉", "橙子", "葡萄")
print(sorted(fruits))
# Out:
# ['橙子', '苹果', '葡萄', '香蕉']
