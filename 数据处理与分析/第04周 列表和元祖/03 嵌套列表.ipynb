# %%
goods1 = ["手机", 10, 2999]
goods2 = ["笔记本电脑", 10, 8999]
goods3 = ["羽绒服", 10, 2999]
goods4 = ["鞋子", 30, 2999]
goods = [["手机", 10, 2999], ["笔记本电脑", 10, 8999], ["羽绒服", 10, 2999], ["鞋子", 30, 2999]]
print(goods)
print(goods[1])
print(goods[1][1])
# Out:
# [['手机', 10, 2999], ['笔记本电脑', 10, 8999], ['羽绒服', 10, 2999], ['鞋子', 30, 2999]]
# ['笔记本电脑', 10, 8999]
# 10

# %%
goods1 = ["手机", 10, 2999]
goods2 = ["笔记本电脑", 10, 8999]
goods3 = ["羽绒服", 10, 2999]
goods4 = ["鞋子", 30, 2999]
goods = [goods1, goods2, goods3, goods4]
print(goods)
print(goods[1])
print(goods[1][1])
# Out:
# [['手机', 10, 2999], ['笔记本电脑', 10, 8999], ['羽绒服', 10, 2999], ['鞋子', 30, 2999]]
# ['笔记本电脑', 10, 8999]
# 10

# %%
orders = [["DD202307001", [["手机", 1, 2999], ["耳机", 2, 199]], "已发货"], ["DD202307002", [["笔记本电脑", 1, 8999], ["鼠标", 1, 89]], "待处理"]]

# %%
for n in numbers:
    n *= 2

# %%
s = ['Google', 'Runoob', 'Taobao']
s.pop(1)
print(s)
# Out:
# ['Google', 'Taobao']
