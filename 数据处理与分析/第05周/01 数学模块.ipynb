# %%
# 计算圆的面积
def calculate_circle_area(radius):
    import math

    area = math.pi * radius**2
    return round(area, 2)


print(calculate_circle_area(4))

# %%
import math

radius = 5
area = math.pi * radius**2
area = round(area, 2)
print(area) # 78.54

# %%
# 计算圆柱体的表面积
import math
radius = float(input())
height = float(input())

def calculate_surface_area(radius, height):
    base_area = 2 * math.pi * radius * radius
    lateral_area = 2 * math.pi * radius * height
    return base_area + lateral_area

surface_area = calculate_surface_area(radius, height)
print(f"圆柱体的表面积为：{surface_area:.4f}")

# %%
# 程序的运行结果是？
students = ['王利达', '赵子政', '张雪', '张三']
if '张三' in students or '李四' in students:
    print('张三在队伍里')
else:
    print('张三不在队伍里')
for i in range(1, 4):
    print('你好')

# %%
import random
random.randrange(1, 10, 3)
# Out:
# 7

# %%
import math

radius = 5
area = math.pi * radius**2
area = round(area, 2)
print(area) # 78.54

# %%
import math as m

radius = 5
area = m.pi * radius**2
area = round(area, 2)
