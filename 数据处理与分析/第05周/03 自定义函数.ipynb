# %%
# 自定义运费计算函数
def delivery_cost(weight):
    if weight <= 1:
        cost = 10
    else:
        cost = 10 + (weight - 1) * 3
    return cost


delivery_cost(6)
# Out:
# 25

# %%
# 介绍宠物
def describe_pet(pet_name, animal_type= '小猫'):
    print(f'我的{animal_type}的名字是{pet_name}')

describe_pet('小猫', '小狗')
# Out:
# 我的小狗的名字是小猫
