# %%
import pandas as pd
import numpy as np

# %%
data = {'name': ['Jack', 'Mary', 'Tom'], 'age': [18, 22, 26], 'gender': ['male', 'female', 'male']}
df = pd.DataFrame(data, index=['a', 'b', 'c'])
print(df.axes)
# Out:
# [Index(['a', 'b', 'c'], dtype='object'), Index(['name', 'age', 'gender'], dtype='object')]

# %%
d = {'Name': pd.Series(['Tom', 'James', 'Ricky', 'Vin', 'Steve', 'Smith', 'Jack']), 'Age': pd.Series([25, 26, 25, 23, 30, 29, 23]), 'Rating': pd.Series([4.23, 3.24, 3.98, 2.56, 3.20, 4.6, 3.8])}
df = pd.DataFrame(d)
print(df.size)
# Out:
# 21
