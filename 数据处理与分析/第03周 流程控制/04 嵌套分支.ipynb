# %%
if current_stock < min_stock:
    print(f'库存不足！请立即补货，当前库存量：{current_stock}')
else:
    print('库存充足！')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 if current_stock < min_stock:
#       2     print(f'库存不足！请立即补货，当前库存量：{current_stock}')
#       3 else:
#
# NameError: name 'current_stock' is not defined

# %%
# 外层判断
if 条件1:
    # 内层判断
    if 条件2:
        执行代码A
    else:
        执行代码B
else:
    # 另一个内层判断
    if 条件3:
        执行代码C
    else:
        执行代码D

# %%
if 下雨:
    if 温度高:
        宅家里
    else:
        去体育馆
else:
    if 温度高:
        去游泳
    else:
        去逛街

# %%
if 条件1:
    if 条件2:
        执行代码A
    else:
        执行代码B
else:
    if 条件3:
        执行代码C
    else:
        执行代码D

# %%
if category == "A":
    if current_stock < 100:
        print("A类缺货")
    else:
        print("A类库存充足")
elif category == "B":
    if current_stock < 500:
        print("B类缺货")
    else:
        print("B类库存充足")
elif category == "C":
    if current_stock < 500:
        print("C类缺货")
    else:
        print("C类库存充足")
