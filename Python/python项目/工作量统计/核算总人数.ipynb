# %%
import pandas as pd

df = pd.read_excel('2024(秋)新教务系统登记.xlsx')
df
# 按课程名称和课序号分组，按人数列求和
df.groupby(['课程名称', '课序号']).sum()
# Out:
#                                                                 教学方式  \
# 课程名称          课序号
# 制药厂生产实习       1                                 分散顶岗分散顶岗分散顶岗分散顶岗分散顶岗
# 化工厂生产实习       1                                 分散顶岗分散顶岗分散顶岗分散顶岗分散顶岗
# 化工国际前沿专题讲座    1    其它实习其它实习其它实习其它实习其它实习其它实习其它实习其它实习其它实习其它实习其它实习其它...
# 基础学科综训与算法基础   2    其它实习其它实习其它实习其它实习其它实习其它实习其它实习其它实习其它实习其它实习其它实习其它...
#               3    其它实习其它实习其它实习其它实习其它实习其它实习其它实习其它实习其它实习其它实习其它实习其它...
# 科技论文写作与科研创新实践 3    其它实习其它实习其它实习其它实习其它实习其它实习其它实习其它实习其它实习其它实习其它实习其它...
#               4    其它实习其它实习其它实习其它实习其它实习其它实习其它实习其它实习其它实习其它实习其它实习其它...
# 科技论文阅读与科研创新训练 3    其它实习其它实习其它实习其它实习其它实习其它实习其它实习其它实习其它实习其它实习其它实习其它...
#               4    其它实习其它实习其它实习其它实习其它实习其它实习其它实习其它实习其它实习其它实习其它实习其它...
# 综合创新化学实验      1    其它实习其它实习其它实习其它实习其它实习其它实习其它实习其它实习其它实习其它实习其它实习其它...
#               2    其它实习其它实习其它实习其它实习其它实习其它实习其它实习其它实习其它实习其它实习其它实习其它...
#
#                                                                 任课教师  \
# 课程名称          课序号
# ...
